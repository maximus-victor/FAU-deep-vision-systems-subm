# %%
# !pip install -q streamlit

# %%
# !pip install pyngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install style

# %%
#!streamlit run /content/drive/MyDrive/DEEPVIS/app_simple.py >/dev/null

# %%
# !pip install grad-cam
# !pip install ttach

# %%
from pyngrok import ngrok
# Setup a tunnel to the streamlit port 8501
public_url = ngrok.connect(port='8501')
public_url
# Out:
# <NgrokTunnel: "http://b35e-35-245-42-61.ngrok.io" -> "http://localhost:80">

# %%
#!streamlit run /content/drive/MyDrive/DEEPVIS/app.py &>/dev/null&
#!streamlit run --server.port 80 /content/drive/MyDrive/DEEPVIS/app_simple.py >/dev/null
# !streamlit run --server.port 80 /content/drive/MyDrive/DEEPVIS/app.py >/dev/null
# Out:
# /content/drive/MyDrive/DEEPVIS/datasets.py:103: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(image, dtype=torch.float)
